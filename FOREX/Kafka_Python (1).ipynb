# %%
# !pip uninstall kafka-python

# %%
# !pip install matplotlib

# %%
# !pip uninstall findspark

# %%
import findspark
findspark.init()
# findspark.find()

# %% [markdown]
# Import required libraries and modules
#
# kafka --> consumer interaction
#
# matplotlib --> for visualization
#
# json --> read file format
#
# threading --> make threads for plots

# %%
from kafka import KafkaConsumer
import matplotlib.pyplot as plt
import json
import threading

# %%
consumer = KafkaConsumer('bidPriceOutput',
                         group_id='bidPriceOutput',
                         bootstrap_servers=['localhost:9092'],
                        )
print("consumer started ...")
# Out:
# consumer started ...

# %%
x = {}

# %%
def plot():
    global x
    for message in consumer:
        x[json.loads((message.value).decode("utf-8"))["quoteTimestamp"]] = json.loads((message.value).decode("utf-8"))["bidPrice"]

# %%
plot_thread = threading.Thread(target=plot)

# %%
plot_thread.start()

# %%
try:
    fig = plt.figure(figsize = (18, 6))
    x = dict(sorted(x.items(), key=lambda item: item[1], reverse=True))

    plt.bar([*x.keys()][:10], [*x.values()][:10], width = 0.5)

    plt.xlabel("Time Stamp", fontsize=15)
    plt.ylabel("Bid Price", fontsize=15)
    plt.title("bidPrice with Quote Time Stamp", fontsize = 20)
    plt.xticks(rotation=90)
    plt.show()
except:
    print(f"atleast 10 data needed but {len(x)} data is there")

# %%
try:
    fig = plt.figure(figsize = (12, 6))
    x = dict(sorted(x.items(), key=lambda item: item[1], reverse=True))

    plt.plot([*x.keys()][:10], [*x.values()][:10])

    plt.xlabel("Time Stamp", fontsize=15)
    plt.ylabel("Bid Price", fontsize=15)
    
    plt.title("bidPrice with Quote Time Stamp", fontsize = 20)
    plt.xticks(rotation=90)
    plt.show()
except:
    print(f"atleast 10 data needed but {len(x)} data is there")

# %%
try:
    fig = plt.figure(figsize = (12, 6))
    x = dict(sorted(x.items(), key=lambda item: item[1], reverse=True))

    plt.plot([*x.keys()][10:50], [*x.values()][10:50], color='blue')

    plt.xlabel("Time Stamp", fontsize=15)
    plt.ylabel("BidPrice",fontsize=15)
    plt.title("bidPrice with Quote Time Stamp", fontsize=15)
    plt.xticks(rotation=90)
    plt.show()
except:
    print(f"atleast 30 records are  needed but {len(x)} records are there")

# %%
# pip install seaborn

# %%
import seaborn as sns
# try:
fig = plt.figure(figsize = (12, 6))
x = dict(sorted(x.items(), key=lambda item: item[1], reverse=True))

sns.lineplot([*x.keys()][10:50], [*x.values()][10:50], color='blue')

plt.xlabel("Time Stamp", fontsize=15)
plt.ylabel("BidPrice",fontsize=15)
plt.title("bidPrice with Quote Time Stamp", fontsize=15)
plt.xticks(rotation=90)
plt.show()
# except:
#     print(f"atleast 30 records are  needed but {len(x)} records are there")
# Out:
# /home/bug/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
# try:
fig = plt.figure(figsize = (12, 6))
x = dict(sorted(x.items(), key=lambda item: item[1], reverse=True))

sns.scatterplot([*x.keys()][10:50], [*x.values()][10:50], color='blue')

plt.xlabel("Time Stamp", fontsize=15)
plt.ylabel("BidPrice",fontsize=15)
plt.title("bidPrice with Quote Time Stamp", fontsize=15)
plt.xticks(rotation=90)
plt.show()
# except:
#     print(f"atleast 30 records are  needed but {len(x)} records are there")
# Out:
# /home/bug/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
import seaborn as sns
# try:
fig = plt.figure(figsize = (12, 6))
x = dict(sorted(x.items(), key=lambda item: item[1], reverse=True))

sns.boxplot([*x.keys()][10:50], [*x.values()][10:50], color='blue')

plt.xlabel("Time Stamp", fontsize=15)
plt.ylabel("BidPrice",fontsize=15)
plt.title("bidPrice with Quote Time Stamp", fontsize=15)
plt.xticks(rotation=90)
plt.show()
# except:
#     print(f"atleast 30 records are  needed but {len(x)} records are there")

# %%
import seaborn as sns
# try:
fig = plt.figure(figsize = (12, 6))
x = dict(sorted(x.items(), key=lambda item: item[1], reverse=True))

sns.violinplot([*x.keys()][10:50], [*x.values()][10:50], color='blue')

plt.xlabel("Time Stamp", fontsize=15)
plt.ylabel("BidPrice",fontsize=15)
plt.title("bidPrice with Quote Time Stamp", fontsize=15)
plt.xticks(rotation=90)
plt.show()
# except:
#     print(f"atleast 30 records are  needed but {len(x)} records are there")
# Out:
# /home/bug/.local/lib/python3.9/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
